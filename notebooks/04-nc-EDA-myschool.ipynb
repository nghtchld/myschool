# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
sns.set(style='ticks', context='talk')

# %%
os.getcwd()
# Out:
# 'P:\\Python\\Jupyter\\Courses\\myschool\\notebooks'

# %%
# setting directories for file loads and saves
logs_dir = "../data/logs/"
data_dir = "../data/raw/"
load_dir = save_dir = "../data/interim/"
final_dir = "../data/processed/"

# %%
# load 2017, Year 7, NAPLAN scrpaed results

xl7 = (pd.read_csv(final_dir + "2017_year_7_results_df.csv", index_col=0)
       .rename(columns=lambda x: x.replace(" ", "_"))
       .rename(columns=str.lower)
       .rename(columns = {'schoolid' : 'school_id'})
      )
xl7.head()
# Out:
#    school_id  grade  year   domain  mean  lower  upper
# 0      40001      7  2017  Reading   589    572    606
# 1      41180      7  2017  Reading   588    579    596
# 2      43478      7  2017  Reading   570    560    581
# 3      43877      7  2017  Reading   595    588    603
# 4      43978      7  2017  Reading   577    566    587

# %%
# load the school profiles 2008 - 2017 spreadsheet df: xl
file = "school_profiles_2008_2017_df.pickle"

xl = pd.read_pickle(data_dir + file)

xl.head()
# Out:
#    calendar_year  school_id                     school_name     suburb state  \
# 0           2008      40000  Corpus Christi Catholic School  BELLERIVE   TAS
# 1           2009      40000  Corpus Christi Catholic School  BELLERIVE   TAS
# 2           2010      40000  Corpus Christi Catholic School  BELLERIVE   TAS
# 3           2011      40000  Corpus Christi Catholic School  BELLERIVE   TAS
# 4           2012      40000  Corpus Christi Catholic School  BELLERIVE   TAS
#
#    postcode school_sector school_type   icsea  bottom_sea_quarter  \
# 0      7018      Catholic     Primary  1055.0                13.0
# 1      7018      Catholic     Primary  1055.0                13.0
# 2      7018      Catholic     Primary  1044.0                28.0
# 3      7018      Catholic     Primary  1046.0                19.0
# 4      7018      Catholic     Primary  1041.0                 9.0
#
#    lower_middle_sea_quarter  upper_middle_sea_quarter  top_sea_quarter  \
# 0                      19.0                      37.0             31.0
# 1                      19.0                      37.0             31.0
# 2                      19.0                      30.0             23.0
# 3                      30.0                      25.0             25.0
# 4                      35.0                      28.0             28.0
#
#    fte_teachers  fte_other_staff  total_enrolments  girls_enrolments  \
# 0          19.0              6.9             410.0             185.0
# 1          19.1              8.7             409.0             184.0
# 2          18.6             10.2             392.0             173.0
# 3          18.1              9.0             385.0             173.0
# 4          18.1              9.4             391.0             185.0
#
#    boys_enrolments  indigenous_enrolments  lote
# 0            225.0                    1.0   NaN
# 1            225.0                    2.0   3.0
# 2            219.0                    2.0   4.0
# 3            212.0                    0.0   2.0
# 4            206.0                    1.0   5.0

# %%
xl.columns
# Out:
# Index(['calendar_year', 'school_id', 'school_name', 'suburb', 'state',
#        'postcode', 'school_sector', 'school_type', 'icsea',
#        'bottom_sea_quarter', 'lower_middle_sea_quarter',
#        'upper_middle_sea_quarter', 'top_sea_quarter', 'fte_teachers',
#        'fte_other_staff', 'total_enrolments', 'girls_enrolments',
#        'boys_enrolments', 'indigenous_enrolments', 'lote'],
#       dtype='object')

# %%
#xl7['mean'].hist(by = xl7['domain'], bins = 50, figsize = (9,12))

# %%
xl_sub = xl.loc[:, ['calendar_year', 'school_id', 'school_name', 'state',
       'postcode', 'school_type', 'icsea',
       'bottom_sea_quarter', 'lower_middle_sea_quarter',
       'upper_middle_sea_quarter', 'top_sea_quarter', 'fte_teachers',
       'fte_other_staff', 'total_enrolments', 'indigenous_enrolments', 'lote']]
xl_sub.head()
# Out:
#    calendar_year  school_id                     school_name state  postcode  \
# 0           2008      40000  Corpus Christi Catholic School   TAS      7018
# 1           2009      40000  Corpus Christi Catholic School   TAS      7018
# 2           2010      40000  Corpus Christi Catholic School   TAS      7018
# 3           2011      40000  Corpus Christi Catholic School   TAS      7018
# 4           2012      40000  Corpus Christi Catholic School   TAS      7018
#
#   school_type   icsea  bottom_sea_quarter  lower_middle_sea_quarter  \
# 0     Primary  1055.0                13.0                      19.0
# 1     Primary  1055.0                13.0                      19.0
# 2     Primary  1044.0                28.0                      19.0
# 3     Primary  1046.0                19.0                      30.0
# 4     Primary  1041.0                 9.0                      35.0
#
#    upper_middle_sea_quarter  top_sea_quarter  fte_teachers  fte_other_staff  \
# 0                      37.0             31.0          19.0              6.9
# 1                      37.0             31.0          19.1              8.7
# 2                      30.0             23.0          18.6             10.2
# 3                      25.0             25.0          18.1              9.0
# 4                      28.0             28.0          18.1              9.4
#
#    total_enrolments  indigenous_enrolments  lote
# 0             410.0                    1.0   NaN
# 1             409.0                    2.0   3.0
# 2             392.0                    2.0   4.0
# 3             385.0                    0.0   2.0
# 4             391.0                    1.0   5.0

# %%
xl_sub_2017 = xl_sub.loc[xl_sub['calendar_year'] == 2017].reset_index(drop=True)
xl_sub_2017.head()
# Out:
#    calendar_year  school_id                               school_name state  \
# 0           2017      40000            Corpus Christi Catholic School   TAS
# 1           2017      40001                              Fahan School   TAS
# 2           2017      40002                  Geneva Christian College   TAS
# 3           2017      40003               Holy Rosary Catholic School   TAS
# 4           2017      40004  Immaculate Heart of Mary Catholic School   TAS
#
#    postcode school_type   icsea  bottom_sea_quarter  lower_middle_sea_quarter  \
# 0      7018     Primary  1063.0                10.0                      27.0
# 1      7005    Combined  1130.0                 4.0                      11.0
# 2      7307    Combined   969.0                34.0                      40.0
# 3      7011     Primary   987.0                31.0                      40.0
# 4      7008     Primary  1006.0                24.0                      32.0
#
#    upper_middle_sea_quarter  top_sea_quarter  fte_teachers  fte_other_staff  \
# 0                      33.0             31.0          20.4              9.4
# 1                      26.0             59.0          33.3             21.7
# 2                      22.0              5.0          14.5             20.8
# 3                      23.0              7.0          21.9             11.0
# 4                      26.0             18.0           9.6              5.3
#
#    total_enrolments  indigenous_enrolments  lote
# 0             399.0                    2.0  44.0
# 1             372.0                    1.0   7.0
# 2             194.0                    8.0   4.0
# 3             397.0                    4.0  46.0
# 4             189.0                    8.0  35.0

# %%
xl_7_2017 = xl7.merge(xl_sub_2017)
xl_7_2017.head()
# Out:
#    school_id  grade  year                   domain  mean  lower  upper  \
# 0      40001      7  2017                  Reading   589    572    606
# 1      40001      7  2017                  Writing   564    544    585
# 2      40001      7  2017                 Spelling   569    550    587
# 3      40001      7  2017  Grammar and Punctuation   593    572    613
# 4      40001      7  2017                 Numeracy   581    564    599
#
#    calendar_year   school_name state  ...    icsea bottom_sea_quarter  \
# 0           2017  Fahan School   TAS  ...   1130.0                4.0
# 1           2017  Fahan School   TAS  ...   1130.0                4.0
# 2           2017  Fahan School   TAS  ...   1130.0                4.0
# 3           2017  Fahan School   TAS  ...   1130.0                4.0
# 4           2017  Fahan School   TAS  ...   1130.0                4.0
#
#    lower_middle_sea_quarter  upper_middle_sea_quarter  top_sea_quarter  \
# 0                      11.0                      26.0             59.0
# 1                      11.0                      26.0             59.0
# 2                      11.0                      26.0             59.0
# 3                      11.0                      26.0             59.0
# 4                      11.0                      26.0             59.0
#
#    fte_teachers  fte_other_staff  total_enrolments  indigenous_enrolments  \
# 0          33.3             21.7             372.0                    1.0
# 1          33.3             21.7             372.0                    1.0
# 2          33.3             21.7             372.0                    1.0
# 3          33.3             21.7             372.0                    1.0
# 4          33.3             21.7             372.0                    1.0
#
#    lote
# 0   7.0
# 1   7.0
# 2   7.0
# 3   7.0
# 4   7.0
#
# [5 rows x 22 columns]

# %%
xl_7_2017.to_csv(save_dir + '2017_year_7_results_schools_info.csv')

# %%
xl7.loc[xl7['domain'] == 'Reading'].describe()

# %%
xl7.groupby(['domain']).mean().round(decimals=2)

# %%
xl.loc[xl['school_id'] == 41811]
# Out:
#        calendar_year  school_id                          school_name  \
# 13484           2008      41811  James Ruse Agricultural High School
# 13485           2009      41811  James Ruse Agricultural High School
# 13486           2010      41811  James Ruse Agricultural High School
# 13487           2011      41811  James Ruse Agricultural High School
# 13488           2012      41811  James Ruse Agricultural High School
# 13489           2013      41811  James Ruse Agricultural High School
# 13490           2014      41811  James Ruse Agricultural High School
# 13491           2015      41811  James Ruse Agricultural High School
# 13492           2016      41811  James Ruse Agricultural High School
# 13493           2017      41811  James Ruse Agricultural High School
#
#             suburb state  postcode school_sector school_type   icsea  \
# 13484  CARLINGFORD   NSW      2118    Government   Secondary  1119.0
# 13485  CARLINGFORD   NSW      2118    Government   Secondary  1119.0
# 13486  CARLINGFORD   NSW      2118    Government   Secondary  1186.0
# 13487  CARLINGFORD   NSW      2118    Government   Secondary  1181.0
# 13488  CARLINGFORD   NSW      2118    Government   Secondary  1176.0
# 13489  CARLINGFORD   NSW      2118    Government   Secondary  1249.0
# 13490  CARLINGFORD   NSW      2118    Government   Secondary  1249.0
# 13491  CARLINGFORD   NSW      2118    Government   Secondary  1262.0
# 13492  CARLINGFORD   NSW      2118    Government   Secondary  1240.0
# 13493  CARLINGFORD   NSW      2118    Government   Secondary  1236.0
#
#        bottom_sea_quarter  lower_middle_sea_quarter  upper_middle_sea_quarter  \
# 13484                 4.0                      13.0                      20.0
# 13485                 4.0                      13.0                      20.0
# 13486                 5.0                       7.0                      23.0
# 13487                 4.0                       3.0                      33.0
# 13488                 2.0                       7.0                      34.0
# 13489                 0.0                       7.0                       8.0
# 13490                 0.0                       0.0                      15.0
# 13491                 0.0                       0.0                      14.0
# 13492                 0.0                       6.0                       5.0
# 13493                 0.0                       0.0                      13.0
#
#        top_sea_quarter  fte_teachers  fte_other_staff  total_enrolments  \
# 13484             63.0          60.5             13.0             844.0
# 13485             63.0          60.7             12.9             843.0
# 13486             66.0          59.1             12.5             845.0
# 13487             59.0          59.4             12.9             856.0
# 13488             57.0          59.3             12.9             856.0
# 13489             85.0          59.5             12.9             853.0
# 13490             85.0          58.8             12.9             840.0
# 13491             86.0          58.7             12.5             839.0
# 13492             89.0          59.1             12.5             843.0
# 13493             87.0          58.7             12.5             841.0
#
#        girls_enrolments  boys_enrolments  indigenous_enrolments  lote
# 13484             365.0            479.0                    0.0   NaN
# 13485             362.0            481.0                    0.0  97.0
# 13486             375.0            470.0                    0.0  97.0
# 13487             383.0            473.0                    0.0  96.0
# 13488             376.0            480.0                    0.0  96.0
# 13489             379.0            474.0                    0.0  97.0
# 13490             367.0            473.0                    0.0  97.0
# 13491             378.0            461.0                    0.0  97.0
# 13492             371.0            472.0                    0.0  97.0
# 13493             378.0            463.0                    0.0  97.0

# %%
# find a particular ACARA school ID, e.g. Corinda State High School = 47449
# Indooroopilly State High School = 47431
# ""Brisbane Boys' College = 48011
name_of_school = "James Ruse Agricultural High School"
yr = 2017

id_of_school = (school_profiles_all.loc[
    (school_profiles_all['School Name'] == name_of_school) & 
    (school_profiles_all['Calendar Year'] == yr)]
                ['ACARA School ID']
                .values[0])

id_of_school

# %%
# get index of school ID in all 2017 results list 
school_all_results_index = xl7.loc[xl7['schoolId'] == id_of_school].index.tolist()

# %%
z = xl7.set_index('schoolId').loc[:, ['domain', 'mean']].groupby(['domain']).rank(method='max', ascending=False)
#len(z)
print('Max of rank:', max(z['mean']), '\nMin of rank', min(z['mean']))

# %%
top_10 = z.sort_values('mean').head(5).index.tolist()
for e in top_10:
    sname = (school_profiles_all.loc[
    (school_profiles_all['ACARA School ID'] == e) & 
    (school_profiles_all['Calendar Year'] == 2017)]
                ['School Name']
                .values[0])
    print(sname,)

# %%
print('Corinda rankings out of', max(z['mean']))
z.loc[47449]

# %%
print('Indooroopilly rankings out of', max(z['mean']))
z.loc[47431]

# %%
print('BBC rankings out of', max(z['mean']))
z.loc[48011]

# %%
print('James Ruse rankings out of', max(z['mean']))
z.loc[41811]
